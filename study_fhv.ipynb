# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_parquet("datas/fhv_tripdata_2015-01.parquet")
df
# Out:
#         dispatching_base_num     pickup_datetime dropOff_datetime  \
# 0                     B00013 2015-01-01 00:30:00       1989-01-01
# 1                     B00014 2015-01-01 00:28:00       1989-01-01
# 2                     B00014 2015-01-01 00:25:00       1989-01-01
# 3                     B00014 2015-01-01 00:13:00       1989-01-01
# 4                     B00014 2015-01-01 00:20:00       1989-01-01
# ...                      ...                 ...              ...
# 2720781               B02765 2015-01-31 23:37:58       1989-01-01
# 2720782               B02765 2015-01-31 23:48:34       1989-01-01
# 2720783               B02765 2015-01-31 23:59:40       1989-01-01
# 2720784               B02765 2015-01-31 23:15:32       1989-01-01
# 2720785               B02765 2015-01-31 23:35:30       1989-01-01
#
#          PUlocationID  DOlocationID SR_Flag Affiliated_base_number
# 0                 NaN           NaN    None                 B00013
# ...

# %%
df["dropOff_datetime"].value_counts()
# Out:
# dropOff_datetime
# 1989-01-01    2720786
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['dispatching_base_num', 'pickup_datetime', 'dropOff_datetime',
#        'PUlocationID', 'DOlocationID', 'SR_Flag', 'Affiliated_base_number'],
#       dtype='object')
